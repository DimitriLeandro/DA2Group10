# %% [markdown]
# <a href="https://colab.research.google.com/github/DimitriLeandro/DA2Group10/blob/main/final_project_part_ii.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import shutil
from random import choice
from pathlib import Path
from IPython.display import Image

# %% [markdown]
# # Downloading and extracting datasets

# %%
# !wget https://uni-muenster.sciebo.de/s/KNjoOrXdWecbvdh/download?path=%2F&files=training_patches.zip
# Out:
# --2022-06-20 15:38:10--  https://uni-muenster.sciebo.de/s/KNjoOrXdWecbvdh/download?path=%2F
# Resolving uni-muenster.sciebo.de (uni-muenster.sciebo.de)... 128.176.4.4
# Connecting to uni-muenster.sciebo.de (uni-muenster.sciebo.de)|128.176.4.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘download?path=%2F’
#
# download?path=%2F       [      <=>           ]   2.48G  31.0MB/s    in 83s
#
# 2022-06-20 15:39:34 (30.7 MB/s) - ‘download?path=%2F’ saved [2662762638]

# %%
# !unzip -q -o /content/download?path=%2F -d /content/

# %%
# !unzip -q -o /content/task_2/training_patches.zip -d /content/task_2/
shutil.rmtree('/content/task_2/__MACOSX')

# %%
# !unzip -q -o /content/task_2/unlabeled_training_data.zip -d /content/task_2/

# %% [markdown]
# # Visualizing images

# %%
training_patches = Path('/content/task_2/training_patches/background/')
Image(filename=str(choice(list(training_patches.iterdir()))))

# %%
training_patches = Path('/content/task_2/training_patches/ponds/')
Image(filename=str(choice(list(training_patches.iterdir()))))

# %%
training_patches = Path('/content/task_2/training_patches/pools/')
Image(filename=str(choice(list(training_patches.iterdir()))))

# %%
training_patches = Path('/content/task_2/training_patches/solar/')
Image(filename=str(choice(list(training_patches.iterdir()))))

# %%
training_patches = Path('/content/task_2/training_patches/trampoline/')
Image(filename=str(choice(list(training_patches.iterdir()))))
